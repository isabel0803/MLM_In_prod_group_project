# %%
import pandas as pd
import numpy as np
import gcsfs
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

import sys
sys.path.append("../models")

from baseline import GroupMeanRegressor

# %%
import os

# Path to your uploaded JSON key — adjust if needed
SERVICE_ACCOUNT_PATH = "../secrets/service_account.json"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = SERVICE_ACCOUNT_PATH

print("Authenticated using service account.")
# Out:
# Authenticated using service account.

# %%
BUCKET = "group_project2"       
TRAIN_PATH = "inputs/train.csv"
VAL_PATH = "inputs/val.csv"

print("Bucket:", BUCKET)
# Out:
# Bucket: group_project2

# %%
fs = gcsfs.GCSFileSystem()

def read_gcs_csv(bucket, filepath):
    full_path = f"{bucket}/{filepath}"
    print("Loading:", full_path)
    with fs.open(full_path) as f:
        return pd.read_csv(f)

train = read_gcs_csv(BUCKET, TRAIN_PATH)
val   = read_gcs_csv(BUCKET, VAL_PATH)

train.head(), val.head()
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/retry.py", line 143, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py", line 485, in _request
#     validate_response(status, contents, path, args)
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/retry.py", line 130, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# Loading: group_project2/inputs/train.csv
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6     with fs.open(full_path) as f:
#       7         return pd.read_csv(f)
# ----> 9 train = read_gcs_csv(BUCKET, TRAIN_PATH)
#      10 val   = read_gcs_csv(BUCKET, VAL_PATH)
#      12 train.head(), val.head()
#
# Cell In[5], line 6, in read_gcs_csv(bucket, filepath)
#       4 full_path = f"{bucket}/{filepath}"
#       5 print("Loading:", full_path)
# ----> 6 with fs.open(full_path) as f:
#       7     return pd.read_csv(f)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/fsspec/spec.py:1349, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1347 else:
#    1348     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1349     f = self._open(
#    1350         path,
#    1351         mode=mode,
#    1352         block_size=block_size,
#    1353         autocommit=ac,
#    1354         cache_options=cache_options,
#    1355         **kwargs,
#    1356     )
#    1357     if compression is not None:
#    1358         from fsspec.compression import compr
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:1755, in GCSFileSystem._open(self, path, mode, block_size, cache_options, acl, consistency, metadata, autocommit, fixed_key_metadata, generation, **kwargs)
#    1753     block_size = self.default_block_size
#    1754 const = consistency or self.consistency
# -> 1755 return GCSFile(
#    1756     self,
#    1757     path,
#    1758     mode,
#    1759     block_size,
#    1760     cache_options=cache_options,
#    1761     consistency=const,
#    1762     metadata=metadata,
#    1763     acl=acl,
#    1764     autocommit=autocommit,
#    1765     fixed_key_metadata=fixed_key_metadata,
#    1766     **kwargs,
#    1767 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:1927, in GCSFile.__init__(self, gcsfs, path, mode, block_size, autocommit, cache_type, cache_options, acl, consistency, metadata, content_type, timeout, fixed_key_metadata, generation, kms_key_name, **kwargs)
#    1925     raise OSError("Attempt to open a bucket")
#    1926 self.generation = _coalesce_generation(generation, path_generation)
# -> 1927 super().__init__(
#    1928     gcsfs,
#    1929     path,
#    1930     mode,
#    1931     block_size,
#    1932     autocommit=autocommit,
#    1933     cache_type=cache_type,
#    1934     cache_options=cache_options,
#    1935     **kwargs,
#    1936 )
#    1937 self.gcsfs = gcsfs
#    1938 self.bucket = bucket
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/fsspec/spec.py:1923, in AbstractBufferedFile.__init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1921         self.size = size
#    1922     else:
# -> 1923         self.size = self.details["size"]
#    1924     self.cache = caches[cache_type](
#    1925         self.blocksize, self._fetch_range, self.size, **cache_options
#    1926     )
#    1927 else:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:1972, in GCSFile.details(self)
#    1969 @property
#    1970 def details(self):
#    1971     if self._details is None:
# -> 1972         self._details = self.fs.info(self.path, generation=self.generation)
#    1973     return self._details
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:1061, in GCSFileSystem._info(self, path, generation, **kwargs)
#    1059 # Check exact file path
#    1060 try:
# -> 1061     exact = await self._get_object(path)
#    1062     # this condition finds a "placeholder" - still need to check if it's a directory
#    1063     if not _is_directory_marker(exact):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:572, in GCSFileSystem._get_object(self, path)
#     569 # Work around various permission settings. Prefer an object get (storage.objects.get), but
#     570 # fall back to a bucket list + filter to object name (storage.objects.list).
#     571 try:
# --> 572     res = await self._call(
#     573         "GET", "b/{}/o/{}", bucket, key, json_out=True, generation=generation
#     574     )
#     575 except OSError as e:
#     576     if not str(e).startswith("Forbidden"):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:492, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     488 async def _call(
#     489     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     490 ):
#     491     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 492     status, headers, info, contents = await self._request(
#     493         method, path, *args, **kwargs
#     494     )
#     495     if json_out:
#     496         return json.loads(contents)
#
# File ~/.local/lib/python3.12/site-packages/decorator.py:224, in decorate.<locals>.fun(*args, **kw)
#     222 if not kwsyntax:
#     223     args, kw = fix(args, kw, sig)
# --> 224 return await caller(func, *(extras + args), **kw)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/retry.py:178, in retry_request(func, retries, *args, **kwargs)
#     176     continue
#     177 logger.exception(f"{func.__name__} non-retriable exception: {e}")
# --> 178 raise e
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/retry.py:143, in retry_request(func, retries, *args, **kwargs)
#     141     if retry > 0:
#     142         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 143     return await func(*args, **kwargs)
#     144 except (
#     145     HttpError,
#     146     requests.exceptions.RequestException,
#    (...)    149     aiohttp.client_exceptions.ClientError,
#     150 ) as e:
#     151     if (
#     152         isinstance(e, HttpError)
#     153         and e.code == 400
#     154         and "requester pays" in e.message
#     155     ):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/core.py:485, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     482 info = r.request_info  # for debug only
#     483 contents = await r.read()
# --> 485 validate_response(status, contents, path, args)
#     486 return status, headers, info, contents
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/gcsfs/retry.py:130, in validate_response(status, content, path, args)
#     128     raise ValueError(f"Bad Request: {path}\n{msg}")
#     129 elif error and not isinstance(error, str):
# --> 130     raise HttpError(error)
#     131 elif status:
#     132     raise HttpError({"code": status, "message": msg})  # text-like
#
# HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
